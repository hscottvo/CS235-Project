# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor

# %%
cols_to_drop = ["profit_margin"]
train_df = pd.read_csv("train.csv")
val_df = pd.read_csv("validation.csv")
# val_df = pd.read_csv("test.csv")
X_train = train_df.drop(columns=cols_to_drop)
X_val = val_df.drop(columns=cols_to_drop)
y_train = train_df["profit_margin"]
y_val = val_df["profit_margin"]

# %%
grid_space = {"max_depth":[3, 5, 10, None],
              "n_estimators":[10, 100, 200],
              "max_features":["sqrt", "log2", None],
              "min_samples_leaf":[1, 2, 4],
              "min_samples_split":[2, 5, 8]
              }
random_forest = RandomForestRegressor()
# grid = GridSearchCV(random_forest, param_grid=grid_space, cv=3)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_val)
rmse = np.sqrt(mean_squared_error(y_pred, y_val))
mae = mean_absolute_error(y_pred, y_val)
rmse_logged = np.sqrt(mean_squared_error(np.log(y_pred), np.log(y_val)))
mae_logged = mean_absolute_error(np.log(y_pred), np.log(y_val))
rmse, mae, rmse_logged, mae_logged
# Out:
# (0.6816250712156187,
#  0.5444692441973978,
#  0.9914571956982925,
#  0.5602500590062938)

# %%
results_df = pd.DataFrame(columns=["max_depth", "n_estimators", "max_features", "min_samples_leaf", "min_samples_split"])
i = 0
for max_depth in [3, 5, 10, None]:
    for n_estimators in [10, 100, 200]:
        for max_features in ["sqrt", "log2", None]:
            for min_samples_leaf in [1, 2, 4]:
                for min_samples_split in [2, 5, 8]:
                    random_forest = RandomForestRegressor(
                        max_depth=max_depth, 
                        n_estimators=n_estimators,
                        max_features=max_features,
                        min_samples_leaf=min_samples_leaf,
                        min_samples_split=min_samples_split,
                        )
                    params_dict = {"max_depth": max_depth, 
                                    "n_estimators": n_estimators, 
                                    "max_features": max_features,
                                    "min_samples_leaf": min_samples_leaf,
                                    "min_samples_split": min_samples_split
                                    }
                    print("training with param dict:\n", params_dict)
                    random_forest.fit(X_train, y_train)
                    y_pred = random_forest.predict(X_val)
                    rmse = np.sqrt(mean_squared_error(y_pred, y_val))
                    mae = mean_absolute_error(y_pred, y_val)
                    rmse_logged = np.sqrt(mean_squared_error(np.log(y_pred), np.log(y_val)))
                    mae_logged = mean_absolute_error(np.log(y_pred), np.log(y_val))
                    new_entry = pd.DataFrame({"max_depth": max_depth, 
                                              "n_estimators": n_estimators, 
                                              "max_features": max_features,
                                              "min_samples_leaf": min_samples_leaf,
                                              "min_samples_split": min_samples_split,
                                              "rmse": rmse,
                                              "rmse_logged": rmse_logged,
                                              "mae": mae,
                                              "mae_logged": mae_logged}, index=[i])
                    i += 1
                    print(f"\tGot results: rmse: {rmse}, rmse_logged: {rmse_logged}, mae: {mae}, mae_logged: {mae_logged}")
                    results_df = pd.concat([results_df, new_entry])
# Out:
# training with param dict:
#  {'max_depth': 3, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.7013346485490819, rmse_logged: 1.0179629573732305, mae: 0.5927905174924822, mae_logged: 0.5873995677820052
# training with param dict:
#  {'max_depth': 3, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.7151069587491029, rmse_logged: 1.0247937316595508, mae: 0.6023308741820329, mae_logged: 0.5938496164229328
# training with param dict:
#  {'max_depth': 3, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.703817981357908, rmse_logged: 1.0195541317133376, mae: 0.5944692830171848, mae_logged: 0.5886952122729376
# training with param dict:
#  {'max_depth': 3, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.7030609320952625, rmse_logged: 1.0176619489432128, mae: 0.5936098569803192, mae_logged: 0.5880858812301739
# training with param dict:
#  {'max_depth': 3, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6949714417714293, rmse_logged: 1.0152117503674083, mae: 0.5856859595914398, mae_logged: 0.5829243465642774
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6983761505684893, rmse_logged: 1.0179405839771865, mae: 0.5893493737016756, mae_logged: 0.5851755379920056
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.6984732431775937, rmse_logged: 1.017800133433596, mae: 0.5890080598071419, mae_logged: 0.5849895675683112
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.6947044690974485, rmse_logged: 1.0154838341733057, mae: 0.5853656846287678, mae_logged: 0.5828214308433232
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.694902113593004, rmse_logged: 1.0156437674001757, mae: 0.5857446838929068, mae_logged: 0.5829453465159663
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6977052175969412, rmse_logged: 1.0170688102181815, mae: 0.5876953401054574, mae_logged: 0.5842914555592817
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6268079221822773, rmse_logged: 0.9682469128074489, mae: 0.5033774463346904, mae_logged: 0.5277803125460113
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6273105134633479, rmse_logged: 0.9686254239206701, mae: 0.5036862213718987, mae_logged: 0.5279982463955749
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.6271740165286243, rmse_logged: 0.9680027753233333, mae: 0.5038494936605171, mae_logged: 0.5279395303128627
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6264069933227155, rmse_logged: 0.9676033304453729, mae: 0.5028606925822507, mae_logged: 0.5270719270110815
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6259547464168884, rmse_logged: 0.9672840378065295, mae: 0.5020457748318341, mae_logged: 0.5262421971232523
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.6258154557609833, rmse_logged: 0.9676868866405774, mae: 0.5022563859090755, mae_logged: 0.5267972432601454
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.626129490711439, rmse_logged: 0.967799635978149, mae: 0.5021379461753209, mae_logged: 0.5269938333795783
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6251661227004329, rmse_logged: 0.9672730595454174, mae: 0.5014366559648603, mae_logged: 0.5263336727228813
# training with param dict:
#  {'max_depth': 5, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6263434802657599, rmse_logged: 0.9677443416603454, mae: 0.5027200576290535, mae_logged: 0.5272840542054666
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6510479735054719, rmse_logged: 0.9860466258545809, mae: 0.5357040978059066, mae_logged: 0.5523112145144633
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6607928430805551, rmse_logged: 0.9927002844621825, mae: 0.5402060072608055, mae_logged: 0.5547317190535545
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.6508245336106118, rmse_logged: 0.9886880743299463, mae: 0.5334180767518651, mae_logged: 0.5501578053190935
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6519483773238945, rmse_logged: 0.9817242837075055, mae: 0.5343913891739579, mae_logged: 0.5489304922724123
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6568040411035753, rmse_logged: 0.9892652789085505, mae: 0.538262687927375, mae_logged: 0.5536837964839763
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.6489548364177045, rmse_logged: 0.9827885307701095, mae: 0.5301287287941523, mae_logged: 0.5462214818701373
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.6436849703607734, rmse_logged: 0.9821793596674312, mae: 0.5274843036637127, mae_logged: 0.545681722276299
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6503821471979009, rmse_logged: 0.9846795551602632, mae: 0.535050685896398, mae_logged: 0.5506049122494475
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6563819327873393, rmse_logged: 0.9857113350900664, mae: 0.5389697780326207, mae_logged: 0.5528893750427676
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6765673359425038, rmse_logged: 1.000607355354739, mae: 0.5610183853432549, mae_logged: 0.5676032491560146
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6701304208144687, rmse_logged: 0.9971781949773089, mae: 0.5579816301310347, mae_logged: 0.5647057986638113
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.6711267997697506, rmse_logged: 1.0019348467073361, mae: 0.5567888531698177, mae_logged: 0.5648632543125927
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6760912464557619, rmse_logged: 1.0032698042864403, mae: 0.5622869250411751, mae_logged: 0.5677858385094869
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6597740816466189, rmse_logged: 0.9943119416385282, mae: 0.5426189255794137, mae_logged: 0.5559270950810935
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.6647465636230401, rmse_logged: 0.9968961793263101, mae: 0.551994680942668, mae_logged: 0.5613395962901578
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.6630962941297679, rmse_logged: 0.9928581121888274, mae: 0.5489468206387037, mae_logged: 0.559293953719698
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6512927009948027, rmse_logged: 0.9869560059519776, mae: 0.5374079830656319, mae_logged: 0.5516976009616307
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6724087288304315, rmse_logged: 1.0029663493252443, mae: 0.5564872204059385, mae_logged: 0.5641133127288187
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6240169402407877, rmse_logged: 0.9525185817203349, mae: 0.48762164598446034, mae_logged: 0.5150989732591488
# training with param dict:
#  {'max_depth': 10, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6172789429779891, rmse_logged: 0.9514565086315055, mae: 0.48175472065090125, mae_logged: 0.5118686848684363
# training with param dict:
# ...
#  {'max_depth': None, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6305445248720954, rmse_logged: 0.9457112662049171, mae: 0.4907353192717851, mae_logged: 0.5184555370861694
# training with param dict:
#  {'max_depth': None, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6386237796321856, rmse_logged: 0.9528383248116901, mae: 0.4870045125275918, mae_logged: 0.5145595077682992
# training with param dict:
#  {'max_depth': None, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.628949992506489, rmse_logged: 0.9510761196280608, mae: 0.4824279268960425, mae_logged: 0.5144679148906958
# training with param dict:
#  {'max_depth': None, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.6220760509906814, rmse_logged: 0.9559744644973068, mae: 0.4812332051744784, mae_logged: 0.511932157401054
# training with param dict:
#  {'max_depth': None, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6307996861227156, rmse_logged: 0.9579165238808413, mae: 0.48651552655651625, mae_logged: 0.5147516392581265
# training with param dict:
#  {'max_depth': None, 'n_estimators': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6164913837807163, rmse_logged: 0.9449561791288416, mae: 0.4768210069868204, mae_logged: 0.506521645099608
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6160519301592032, rmse_logged: 0.9586321123793056, mae: 0.49457743626575446, mae_logged: 0.522225782427158
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6199057046785859, rmse_logged: 0.9607875037451344, mae: 0.5011500206708223, mae_logged: 0.526395592465735
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.6209061521085674, rmse_logged: 0.9625168788629033, mae: 0.5026193719591434, mae_logged: 0.5275429223855125
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6204279480465981, rmse_logged: 0.9638558157630195, mae: 0.5026844143897781, mae_logged: 0.5273982643679686
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6219010422420881, rmse_logged: 0.9641342863636607, mae: 0.5011982614314168, mae_logged: 0.5262280968183374
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.621863399767037, rmse_logged: 0.9652436022750666, mae: 0.5032419760039422, mae_logged: 0.527592507671778
# training with param dict:
#  {'max_depth': None, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6231335554314064, rmse_logged: 0.96739002113707, mae: 0.5059447871537499, mae_logged: 0.5295659109092798
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.622777639657315, rmse_logged: 0.9673245748013002, mae: 0.5063413696201068, mae_logged: 0.5301393062303469
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6205306364961739, rmse_logged: 0.9642874957486496, mae: 0.5034633345419188, mae_logged: 0.5283597741538526
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6239839639246444, rmse_logged: 0.9679909702485573, mae: 0.5077695817842354, mae_logged: 0.5315140309619953
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.6241051585435065, rmse_logged: 0.9669042527050519, mae: 0.5067987519156542, mae_logged: 0.5307169649132208
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6257565482351879, rmse_logged: 0.9709432494369918, mae: 0.5090909422109579, mae_logged: 0.5324187691845349
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6230437403662632, rmse_logged: 0.9673002934055608, mae: 0.5068493793454196, mae_logged: 0.5300068547623684
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.6267264792960993, rmse_logged: 0.9708242697862947, mae: 0.5109035899378191, mae_logged: 0.5330992650000953
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.6332536230427086, rmse_logged: 0.9748457813425138, mae: 0.5190175666170567, mae_logged: 0.5387145099059995
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6331757989694659, rmse_logged: 0.9752750311985221, mae: 0.518235530081663, mae_logged: 0.5383668436262925
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6332078101298638, rmse_logged: 0.9747919063931947, mae: 0.5187701103219778, mae_logged: 0.5386318154077384
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 	Got results: rmse: 0.6055522035051055, rmse_logged: 0.9420534169621276, mae: 0.47285848835497885, mae_logged: 0.504016547067781
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 	Got results: rmse: 0.6093835221565125, rmse_logged: 0.9427959272045944, mae: 0.47586463971223186, mae_logged: 0.5063709809131108
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8}
# 	Got results: rmse: 0.6070269757815367, rmse_logged: 0.9435453492125172, mae: 0.47426081522616687, mae_logged: 0.5050502761077634
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 	Got results: rmse: 0.6053885092985869, rmse_logged: 0.9430762654708024, mae: 0.4702786736859635, mae_logged: 0.5026626277788734
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 	Got results: rmse: 0.6062181875745402, rmse_logged: 0.9428674234461781, mae: 0.4712661660793065, mae_logged: 0.5030652354032484
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 	Got results: rmse: 0.608808016950895, rmse_logged: 0.9459228563571882, mae: 0.47339293855336567, mae_logged: 0.504537227031917
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 	Got results: rmse: 0.6051059248204929, rmse_logged: 0.9439182857282803, mae: 0.47012763465973667, mae_logged: 0.5023282411962063
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 	Got results: rmse: 0.6044230187671776, rmse_logged: 0.9424413717655967, mae: 0.4717820814044419, mae_logged: 0.5036377539951451
# training with param dict:
#  {'max_depth': None, 'n_estimators': 200, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8}
# 	Got results: rmse: 0.6047829675791082, rmse_logged: 0.9433290365496465, mae: 0.4712877578230025, mae_logged: 0.5037071043867825

# %%
results_df.sort_values(by="rmse_logged")
# Out:
#     max_depth n_estimators max_features min_samples_leaf min_samples_split  \
# 288      None          100         None                1                 2
# 263      None           10         None                1                 8
# 315      None          200         None                1                 2
# 322      None          200         None                4                 5
# 316      None          200         None                1                 5
# ..        ...          ...          ...              ...               ...
# 10          3           10         log2                1                 5
# 64          3          200         log2                1                 5
# 4           3           10         sqrt                2                 5
# 15          3           10         log2                4                 2
# 14          3           10         log2                2                 8
#
#          rmse  rmse_logged       mae  mae_logged
# 288  0.609706     0.940923  0.476742    0.506308
# 263  0.629734     0.941950  0.490238    0.519566
# 315  0.605552     0.942053  0.472858    0.504017
# 322  0.604423     0.942441  0.471782    0.503638
# 316  0.609384     0.942796  0.475865    0.506371
# ..        ...          ...       ...         ...
# 10   0.720194     1.030259  0.612010    0.599589
# 64   0.721065     1.030595  0.611759    0.599348
# 4    0.720969     1.030741  0.607670    0.597127
# 15   0.727407     1.030896  0.617269    0.603187
# 14   0.735483     1.038119  0.624930    0.607676
#
# [324 rows x 9 columns]

# %%
rmse, mae, rmse_logged, mae_logged
# Out:
# (0.6816250712156187,
#  0.5444692441973978,
#  0.9914571956982925,
#  0.5602500590062938)

# %%
rmse = np.sqrt(mean_squared_error(y_pred, y_val))
rmse
# Out:
# 0.668980640702459

# %%
mae = mean_absolute_error(y_pred, y_val)
mae
# Out:
# 0.5457130952545353

# %%
pd.Series(np.log(y_pred)).hist()
# Out:
# <Axes: >

# %%
pd.Series(np.log(y_val[np.log(y_val) > -0.5])).hist()
# Out:
# <Axes: >

# %%
# pd.Series(y_val).hist()
plt.hist(np.abs(np.log(y_val) - np.log(y_pred)))
# Out:
# (array([557., 110.,  27.,  17.,  16.,  11.,   7.,   5.,   3.,   4.]),
#  array([4.25061782e-04, 5.45838991e-01, 1.09125292e+00, 1.63666685e+00,
#         2.18208078e+00, 2.72749471e+00, 3.27290864e+00, 3.81832257e+00,
#         4.36373650e+00, 4.90915043e+00, 5.45456436e+00]),
#  <BarContainer object of 10 artists>)

# %%
random_forest_second_best = RandomForestRegressor(n_estimators=10, min_samples_split=8)
random_forest_default = RandomForestRegressor()
random_forest_default.fit(X_train, y_train)
random_forest_second_best.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=8, n_estimators=10)

# %%
test_df = pd.read_csv("test.csv")
X_test = test_df.drop(columns="profit_margin")
y_test = test_df["profit_margin"]
y_pred_test_default = random_forest_default.predict(X_test)
y_pred_test_second_best = random_forest_second_best.predict(X_test)

# %%
# default
stats.ttest_ind(y_test, y_pred_test_default)
# Out:
# TtestResult(statistic=-0.04046110298142949, pvalue=0.9677308516665186, df=1514.0)

# %%
# default
np.sqrt(mean_squared_error(y_test, y_pred_test_default))
# Out:
# 0.6311355018729137

# %%
# default
mean_absolute_error(y_test, y_pred_test_default)
# Out:
# 0.5085941284966687

# %%
# second best
stats.ttest_ind(y_test, y_pred_test_second_best)
# Out:
# TtestResult(statistic=0.06843524517653446, pvalue=0.9454482026990194, df=1514.0)

# %%
# second best 
np.sqrt(mean_squared_error(y_test, y_pred_test_second_best))
# Out:
# 0.6509411051267914

# %%
mean_absolute_error(y_test, y_pred_test_second_best)
# Out:
# 0.5172744035979752

# %%
total_X = pd.concat([X_train, X_val])
total_y = pd.concat([y_train, y_val])
default_cross_val = cross_val_score(random_forest_default, total_X, total_y, cv=10)
default_cross_val.mean()
# Out:
# 0.35000981272491966

# %%
second_best_cross_val = cross_val_score(random_forest_second_best, total_X, total_y, cv=10)
second_best_cross_val.mean()
# Out:
# 0.3096244830195671

# %%
y_pred_val = random_forest_default.predict(X_val)
plt.hist(np.abs(y_pred_val - y_val))
# plt.title("Histogram of Absolute Error between Predictions and Validation")
plt.xlabel("Error")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
